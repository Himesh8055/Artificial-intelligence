# %% [markdown]
# ## Artificial Intelligence and Machine Learning Mini Project

# %% [markdown]
# ## a) Classification

# %% [markdown]
# ## Detect missing values with pandas dataframe.

# %%
import pandas as p
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
info=df.info()
print("\n\n\nis_na:\n\n",df.isna().head(7))
is_null_su=df.isna().sum()
print("\n\n\nCount of all Missing values:\n\n",df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loan_ID             49 non-null     object
#  1   Gender              48 non-null     object
#  2   Married             49 non-null     object
#  3   Dependents          49 non-null     object
#  4   Education           49 non-null     object
#  5   Self_Employed       44 non-null     object
#  6   ApplicantIncome     49 non-null     float64
#  7   Coapplicant_Income  49 non-null     float64
#  8   LoanAmount          47 non-null     float64
#  9   Loan_Amount_Term    45 non-null     float64
#  10  Credit_History      45 non-null     float64
#  11  Cibil_Score         49 non-null     float64
#  12   Loan_Status        50 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 5.2+ KB
#
#
#
# is_na:
#
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    False   False    False       False      False          False
# 1    False   False    False       False      False          False
# 2    False   False    False       False      False          False
# 3    False   False    False       False      False          False
# 4    False   False    False       False      False          False
# 5    False   False    False       False      False          False
# 6    False   False    False       False      False          False
#
#    ApplicantIncome  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0            False               False        True             False
# 1            False               False       False             False
# 2            False               False       False             False
# 3            False               False       False             False
# 4            False               False       False             False
# 5            False               False       False             False
# 6            False               False       False             False
#
#    Credit_History  Cibil_Score   Loan_Status
# 0           False        False         False
# 1           False        False         False
# 2           False        False         False
# 3           False        False         False
# 4           False        False         False
# 5           False        False         False
# 6           False        False         False
#
#
#
# Count of all Missing values:
#
#  Loan_ID               1
# Gender                2
# Married               1
# Dependents            1
# Education             1
# Self_Employed         6
# ApplicantIncome       1
# Coapplicant_Income    1
# LoanAmount            3
# Loan_Amount_Term      5
# Credit_History        5
# Cibil_Score           1
#  Loan_Status          0
# dtype: int64

# %% [markdown]
# ## Replacing with values

# %%
import numpy as n
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
print(df.isna().sum())
df=df.replace({n.nan:-1})
print("\n\n\n")
print(df.isna().sum())
# Out:
# Loan_ID               1
# Gender                2
# Married               1
# Dependents            1
# Education             1
# Self_Employed         6
# ApplicantIncome       1
# Coapplicant_Income    1
# LoanAmount            3
# Loan_Amount_Term      5
# Credit_History        5
# Cibil_Score           1
#  Loan_Status          0
# dtype: int64
#
#
#
#
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# Coapplicant_Income    0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Cibil_Score           0
#  Loan_Status          0
# dtype: int64

# %% [markdown]
# ## Covarience and correlation

# %%
# Select numeric columns for covariance and correlation calculations
numeric_columns = [
     'ApplicantIncome', 'LoanAmount'
]

# Drop rows with missing values in the selected columns
df_numeric = df[numeric_columns].dropna()

# Calculate covariance matrix
cov_matrix = df_numeric.cov()
print("Covariance Matrix:")
print(cov_matrix)
print("\n")
# Calculate correlation matrix
corr_matrix = df_numeric.corr()
print("Correlation Matrix:")
print(corr_matrix)
# Out:
# Covariance Matrix:
#                  ApplicantIncome     LoanAmount
# ApplicantIncome     5.848944e+06  122864.573469
# LoanAmount          1.228646e+05    5523.316327
#
#
# Correlation Matrix:
#                  ApplicantIncome  LoanAmount
# ApplicantIncome         1.000000    0.683578
# LoanAmount              0.683578    1.000000

# %% [markdown]
# ## Removing the attributes with missing values

# %%
import pandas as p
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
print("\nBefore Droping:\n")
df.info()
df=df.dropna(axis=1)
print('\n\nAfter Droping:\n')
df.info()
# Out:
# Before Droping:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loan_ID             49 non-null     object
#  1   Gender              48 non-null     object
#  2   Married             49 non-null     object
#  3   Dependents          49 non-null     object
#  4   Education           49 non-null     object
#  5   Self_Employed       44 non-null     object
#  6   ApplicantIncome     49 non-null     float64
#  7   Coapplicant_Income  49 non-null     float64
#  8   LoanAmount          47 non-null     float64
#  9   Loan_Amount_Term    45 non-null     float64
#  10  Credit_History      45 non-null     float64
#  11  Cibil_Score         49 non-null     float64
#  12   Loan_Status        50 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 5.2+ KB
#
#
# After Droping:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    Loan_Status  50 non-null     object
# dtypes: object(1)
# memory usage: 532.0+ bytes

# %% [markdown]
# ## Replacing with Mean Value

# %%
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['ApplicantIncome'] = p.to_numeric(df['ApplicantIncome'], errors='coerce')
print("Before Replacing:\n\n",df['ApplicantIncome'].head(8))
print("\nMean of 'ApplicantIncome' Column:",df['ApplicantIncome'].mean())
dp=df['ApplicantIncome'].fillna(df['ApplicantIncome'].mean())
print("\nAfter Replacing with Mean:\n\n",dp.head(8))
# Out:
# Before Replacing:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64
#
# Mean of 'ApplicantIncome' Column: 4160.408163265306
#
# After Replacing with Mean:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ## Replacing with Median value

# %%
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['ApplicantIncome'] = p.to_numeric(df['ApplicantIncome'], errors='coerce')
print("Before Replacing:\n\n",df['ApplicantIncome'].head(8))
print("\nMedian of 'ApplicantIncome' Column:",df['ApplicantIncome'].median())
dp=df['ApplicantIncome'].fillna(df['ApplicantIncome'].mean())
print("\nAfter Replacing with Mean:\n\n",dp.head(8))
# Out:
# Before Replacing:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64
#
# Median of 'ApplicantIncome' Column: 3600.0
#
# After Replacing with Mean:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ## Replacing with Mode value

# %%
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['ApplicantIncome'] = p.to_numeric(df['ApplicantIncome'], errors='coerce')
print("Before Replacing:\n\n",df['ApplicantIncome'].head(8))
print("\nMode of 'ApplicantIncome' Column:",df['ApplicantIncome'].mode())
dp=df['ApplicantIncome'].fillna(df['ApplicantIncome'].mean())
print("\nAfter Replacing with Mean:\n\n",dp.head(8))
# Out:
# Before Replacing:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64
#
# Mode of 'ApplicantIncome' Column: 0    2600.0
# 1    4166.0
# Name: ApplicantIncome, dtype: float64
#
# After Replacing with Mean:
#
#  0    5849.0
# 1    4583.0
# 2    3000.0
# 3    2583.0
# 4    6000.0
# 5    5417.0
# 6    2333.0
# 7    3036.0
# Name: ApplicantIncome, dtype: float64

# %% [markdown]
# ## Univariate Outliers

# %%
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sns
df = p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['ApplicantIncome'] = p.to_numeric(df['ApplicantIncome'], errors='coerce')
Q1 = df['ApplicantIncome'].quantile(0.25)
Q3 = df['ApplicantIncome'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['ApplicantIncome'] < lower_bound) | (df['ApplicantIncome'] > upper_bound)]
print("Identified Outliers:\n", outliers)
df_no_outliers = df[(df['ApplicantIncome'] >= lower_bound) & (df['ApplicantIncome'] <= upper_bound)]
print("\nOriginal DataFrame shape:", df.shape)
print("DataFrame shape after removing outliers:", df_no_outliers.shape)
plt.figure(figsize=(10, 6))
sns.boxplot(df['ApplicantIncome'])
plt.xlabel('ApplicantIncome')
plt.ylabel('values')
plt.title('Boxplot of ApplicantIncome')
plt.show()
# Out:
# Identified Outliers:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 9   LP001020   Male     Yes          1  Graduate            No
# 25  LP001066   Male     Yes          0  Graduate           Yes
# 34  LP001100   Male      No         3+  Graduate            No
#
#     ApplicantIncome  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 9           12841.0             10968.0       349.0             360.0
# 25           9560.0                 0.0       191.0             360.0
# 34          12500.0              3000.0       320.0             360.0
#
#     Credit_History  Cibil_Score  Loan_Status
# 9              1.0        388.0     Rejected
# 25             1.0        514.0     Rejected
# 34             1.0        612.0     Approved
#
# Original DataFrame shape: (50, 13)
# DataFrame shape after removing outliers: (46, 13)

# %% [markdown]
# ## Multivariate Outliers

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['ApplicantIncome'] = pd.to_numeric(df['ApplicantIncome'], errors='coerce')
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.boxplot(df['ApplicantIncome'].dropna(), vert=False)
plt.title('Boxplot of ApplicantIncome')
plt.xlabel('ApplicantIncome')
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the dataset
df = pd.read_csv('C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv')
 
info=df.info() 

print("\n\n\nis_na:\n\n",df.isna().head(7)) 
 
is_null_su=df.isna().sum() 
print("\n\n\nCount of all Missing values:\n\n",df.isna().sum())

# Display the first few rows of the dataframe to understand its structure
print("Data:\n ",df.head())

# Select numeric columns for covariance and correlation calculations
numeric_columns = ['ApplicantIncome', 'Coapplicant_Income', 'LoanAmount', 'Loan_Amount_Term','Credit_History', 'Cibil_Score']

# Drop rows with missing values in the selected columns
df_numeric = df[numeric_columns].dropna()

# Calculate covariance matrix
cov_matrix = df_numeric.cov()
print("Covariance Matrix:")
print(cov_matrix)

# Calculate correlation matrix
corr_matrix = df_numeric.corr()
print("Correlation Matrix:")
print(corr_matrix)

# Calculate mean and median for numeric columns
mean_values = df[numeric_columns].mean()
median_values = df[numeric_columns].median()

print("Mean Values:")
print(mean_values)
print("\nMedian Values:")
print(median_values)

# Specify the column you want to plot
column_to_plot = 'LoanAmount'

# Create a histogram for the specified column (univariate)
plt.figure(figsize=(10, 6))
sns.histplot(df[column_to_plot].dropna(), bins=30, kde=True)  
plt.title(f'Histogram of {column_to_plot}')
plt.xlabel(column_to_plot)
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

#Multivariate
plt.figure(figsize=(16, 10))
df.boxplot(column=numeric_columns)
plt.xticks(rotation=45, ha='right')
plt.title('Box Plot for Numeric Columns')
plt.ylabel('Values')
plt.show()

#Comparision plot of Univariate and Multivariate 
plt.figure(figsize=(12, 8))
sns.boxplot(x='Education', y='Self_Employed', data=df)
plt.xticks(rotation=45)  
plt.title('Employment Distribution by Education')
plt.xlabel('Education')
plt.ylabel('Employment')
plt.show()

df_melted = df.melt(value_vars=numeric_columns, var_name='Variable', value_name='Value')
plt.figure(figsize=(14, 8))
sns.boxplot(x='Variable', y='Value', data=df_melted)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.title('Boxplot of Numeric Variables')
plt.xlabel('Variable')
plt.ylabel('Value')
plt.show()

#Univariate and Multivariate composition plots
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender')
plt.show()

df_numeric = df[numeric_columns]
df.set_index('LoanAmount', inplace=True)

ax = df_numeric.plot(kind='bar', stacked=True, figsize=(14, 8), colormap='tab20')

plt.title('Stacked Bar Plot of Numeric Variables by Loan Amount')
plt.xlabel('Loan Amount')
plt.ylabel('Value')
plt.legend(title='Variable', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()  # Adjust layout to fit labels and legend
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Loan_ID             49 non-null     object
#  1   Gender              48 non-null     object
#  2   Married             49 non-null     object
#  3   Dependents          49 non-null     object
#  4   Education           49 non-null     object
#  5   Self_Employed       44 non-null     object
#  6   ApplicantIncome     49 non-null     float64
#  7   Coapplicant_Income  49 non-null     float64
#  8   LoanAmount          47 non-null     float64
#  9   Loan_Amount_Term    45 non-null     float64
#  10  Credit_History      45 non-null     float64
#  11  Cibil_Score         49 non-null     float64
#  12  Loan_Status         50 non-null     object
# dtypes: float64(6), object(7)
# memory usage: 5.2+ KB
#
#
#
# is_na:
#
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0    False   False    False       False      False          False
# 1    False   False    False       False      False          False
# 2    False   False    False       False      False          False
# 3    False   False    False       False      False          False
# 4    False   False    False       False      False          False
# 5    False   False    False       False      False          False
# 6    False   False    False       False      False          False
#
#    ApplicantIncome  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0            False               False        True             False
# 1            False               False       False             False
# 2            False               False       False             False
# 3            False               False       False             False
# 4            False               False       False             False
# 5            False               False       False             False
# 6            False               False       False             False
#
#    Credit_History  Cibil_Score  Loan_Status
# 0           False        False        False
# 1           False        False        False
# 2           False        False        False
# 3           False        False        False
# 4           False        False        False
# 5           False        False        False
# 6           False        False        False
#
#
#
# Count of all Missing values:
#
#  Loan_ID               1
# Gender                2
# Married               1
# Dependents            1
# Education             1
# Self_Employed         6
# ApplicantIncome       1
# Coapplicant_Income    1
# LoanAmount            3
# Loan_Amount_Term      5
# Credit_History        5
# Cibil_Score           1
# Loan_Status           0
# dtype: int64
# Data:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  Coapplicant_Income  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                 0.0         NaN             360.0
# 1           4583.0              1508.0       128.0             360.0
# 2           3000.0                 0.0        66.0             360.0
# 3           2583.0              2358.0       120.0             360.0
# 4           6000.0                 0.0       141.0             360.0
#
#    Credit_History  Cibil_Score Loan_Status
# 0             1.0        778.0    Approved
# 1             1.0        417.0    Rejected
# 2             1.0        506.0    Rejected
# 3             1.0        467.0    Rejected
# 4             1.0        382.0    Rejected
# Covariance Matrix:
#                     ApplicantIncome  Coapplicant_Income     LoanAmount  \
# ApplicantIncome        6.568476e+06        1.876382e+06  138169.847503
# Coapplicant_Income     1.876382e+06        5.904644e+06  127353.940621
# LoanAmount             1.381698e+05        1.273539e+05    5487.009447
# Loan_Amount_Term       1.921668e+04        5.443887e+03     731.821862
# Credit_History         8.510121e+01        5.041296e+01       2.927126
# Cibil_Score           -4.666622e+04       -5.954946e+04   -1987.492578
#
#                     Loan_Amount_Term  Credit_History   Cibil_Score
# ApplicantIncome         19216.680162       85.101215 -46666.221323
# Coapplicant_Income       5443.886640       50.412955 -59549.460189
# LoanAmount                731.821862        2.927126  -1987.492578
# Loan_Amount_Term         1476.923077       -0.971660    532.145749
# Credit_History             -0.971660        0.133603      9.119433
# Cibil_Score               532.145749        9.119433  31986.932524
# Correlation Matrix:
#                     ApplicantIncome  Coapplicant_Income  LoanAmount  \
# ApplicantIncome            1.000000            0.301295    0.727802
# Coapplicant_Income         0.301295            1.000000    0.707535
# LoanAmount                 0.727802            0.707535    1.000000
# Loan_Amount_Term           0.195104            0.058295    0.257074
# Credit_History             0.090844            0.056759    0.108110
# Cibil_Score               -0.101808           -0.137023   -0.150021
#
#                     Loan_Amount_Term  Credit_History  Cibil_Score
# ApplicantIncome             0.195104        0.090844    -0.101808
# Coapplicant_Income          0.058295        0.056759    -0.137023
# LoanAmount                  0.257074        0.108110    -0.150021
# Loan_Amount_Term            1.000000       -0.069171     0.077422
# Credit_History             -0.069171        1.000000     0.139500
# Cibil_Score                 0.077422        0.139500     1.000000
# Mean Values:
# ApplicantIncome       4160.408163
# Coapplicant_Income    1819.612245
# LoanAmount             129.957447
# Loan_Amount_Term       352.000000
# Credit_History           0.844444
# Cibil_Score            556.979592
# dtype: float64
#
# Median Values:
# ApplicantIncome       3600.0
# Coapplicant_Income    1508.0
# LoanAmount             115.0
# Loan_Amount_Term       360.0
# Credit_History           1.0
# Cibil_Score            547.0
# dtype: float64

# %% [markdown]
# ## Standard Deviation

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df['LoanAmount'] = pd.to_numeric(df['LoanAmount'], errors='coerce')
std = df['LoanAmount'].std()
print("Standard Deviation of LoanAmount:", std)
# Out:
# Standard Deviation of LoanAmount: 69.51382641535942

# %% [markdown]
# ## Perform SVC/SVR , Random Forest Regressor/Random Forest Classifier for Mini Project (both Regression and Classification Datasets)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df.drop(columns=['Loan_ID'], inplace=True)
df.dropna(axis=0,inplace=True)
labelencoder = LabelEncoder()
for column in ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Loan_Status']:
    df[column] = labelencoder.fit_transform(df[column])
X = df.drop(columns=['Loan_Status'])  
y = df['Loan_Status']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy of RandomForestClassifier: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy of RandomForestClassifier:  0.9090909090909091

# %%
model1 = SVC(kernel='rbf',random_state=1,gamma='auto')
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print("Accuracy of SupportVectorClassifier: ",accuracy_score(y_test,y_pred1))
# Out:
# Accuracy of SupportVectorClassifier:  0.36363636363636365

# %% [markdown]
# ## b) Regression

# %% [markdown]
# ## Detect missing values with pandas dataframe.

# %%
import pandas as p
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
info=df.info()
print("\n\n\nis_na:\n\n",df.isna().head(7))
is_null_su=df.isna().sum()
print("\n\n\nCount of all Missing values:\n\n",df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  50 non-null     object
#  1   Name                         50 non-null     object
#  2   Gender                       50 non-null     object
#  3   Age                          50 non-null     int64
#  4   Income (USD)                 46 non-null     float64
#  5   Profession                   50 non-null     object
#  6   Location                     50 non-null     object
#  7   Loan Amount Request (USD)    50 non-null     float64
#  8   Current Loan Expenses (USD)  50 non-null     float64
#  9   Credit Score                 49 non-null     float64
#  10  Has Active Credit Card       46 non-null     object
#  11  Property ID                  50 non-null     int64
#  12  Property Age                 46 non-null     float64
#  13  Property Location            50 non-null     object
#  14  Property Price               50 non-null     float64
#  15  Loan Sanction Amount (INR)   50 non-null     float64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 6.4+ KB
#
#
#
# is_na:
#
#     Customer ID   Name  Gender    Age  Income (USD)  Profession  Location  \
# 0        False  False   False  False         False       False     False
# 1        False  False   False  False         False       False     False
# 2        False  False   False  False         False       False     False
# 3        False  False   False  False          True       False     False
# 4        False  False   False  False         False       False     False
# 5        False  False   False  False         False       False     False
# 6        False  False   False  False         False       False     False
#
#    Loan Amount Request (USD)  Current Loan Expenses (USD)  Credit Score  \
# 0                      False                        False         False
# 1                      False                        False         False
# 2                      False                        False         False
# 3                      False                        False         False
# 4                      False                        False         False
# 5                      False                        False         False
# 6                      False                        False         False
#
#    Has Active Credit Card  Property ID  Property Age  Property Location  \
# 0                    True        False         False              False
# 1                   False        False         False              False
# 2                   False        False         False              False
# 3                   False        False          True              False
# 4                   False        False         False              False
# 5                   False        False         False              False
# 6                   False        False         False              False
#
#    Property Price  Loan Sanction Amount (INR)
# 0           False                       False
# 1           False                       False
# 2           False                       False
# 3           False                       False
# 4           False                       False
# 5           False                       False
# 6           False                       False
#
#
#
# Count of all Missing values:
#
#  Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   4
# Profession                     0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Credit Score                   1
# Has Active Credit Card         4
# Property ID                    0
# Property Age                   4
# Property Location              0
# Property Price                 0
# Loan Sanction Amount (INR)     0
# dtype: int64

# %% [markdown]
# ## Replacing with values

# %%
import numpy as n
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
print(df.isna().sum())
df=df.replace({n.nan:-1})
print("\n\n\n")
print(df.isna().sum())
# Out:
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   4
# Profession                     0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Credit Score                   1
# Has Active Credit Card         4
# Property ID                    0
# Property Age                   4
# Property Location              0
# Property Price                 0
# Loan Sanction Amount (INR)     0
# dtype: int64
#
#
#
#
# Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   0
# Profession                     0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Credit Score                   0
# Has Active Credit Card         0
# Property ID                    0
# Property Age                   0
# Property Location              0
# Property Price                 0
# Loan Sanction Amount (INR)     0
# dtype: int64

# %% [markdown]
# ## Covarience and correlation

# %%
# Select numeric columns for covariance and correlation calculations
numeric_columns = [
     'Income (USD)', 'Loan Amount Request (USD)'
]

# Drop rows with missing values in the selected columns
df_numeric = df[numeric_columns].dropna()

# Calculate covariance matrix
cov_matrix = df_numeric.cov()
print("Covariance Matrix:")
print(cov_matrix)
print("\n")
# Calculate correlation matrix
corr_matrix = df_numeric.corr()
print("Correlation Matrix:")
print(corr_matrix)
# Out:
# Covariance Matrix:
#                            Income (USD)  Loan Amount Request (USD)
# Income (USD)               2.442412e+06               1.865142e+07
# Loan Amount Request (USD)  1.865142e+07               2.914031e+09
#
#
# Correlation Matrix:
#                            Income (USD)  Loan Amount Request (USD)
# Income (USD)                   1.000000                   0.221083
# Loan Amount Request (USD)      0.221083                   1.000000

# %% [markdown]
# ## Removing the attributes with missing values

# %%
import pandas as p
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
print("\nBefore Droping:\n")
df.info()
df=df.dropna(axis=1)
print('\n\nAfter Droping:\n')
df.info()
# Out:
# Before Droping:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  50 non-null     object
#  1   Name                         50 non-null     object
#  2   Gender                       50 non-null     object
#  3   Age                          50 non-null     int64
#  4   Income (USD)                 46 non-null     float64
#  5   Profession                   50 non-null     object
#  6   Location                     50 non-null     object
#  7   Loan Amount Request (USD)    50 non-null     float64
#  8   Current Loan Expenses (USD)  50 non-null     float64
#  9   Credit Score                 49 non-null     float64
#  10  Has Active Credit Card       46 non-null     object
#  11  Property ID                  50 non-null     int64
#  12  Property Age                 46 non-null     float64
#  13  Property Location            50 non-null     object
#  14  Property Price               50 non-null     float64
#  15  Loan Sanction Amount (INR)   50 non-null     float64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 6.4+ KB
#
#
# After Droping:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  50 non-null     object
#  1   Name                         50 non-null     object
#  2   Gender                       50 non-null     object
#  3   Age                          50 non-null     int64
#  4   Profession                   50 non-null     object
#  5   Location                     50 non-null     object
#  6   Loan Amount Request (USD)    50 non-null     float64
#  7   Current Loan Expenses (USD)  50 non-null     float64
#  8   Property ID                  50 non-null     int64
#  9   Property Location            50 non-null     object
#  10  Property Price               50 non-null     float64
#  11  Loan Sanction Amount (INR)   50 non-null     float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 4.8+ KB

# %% [markdown]
# ## Replacing with Mean Value

# %%
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Income (USD)'] = p.to_numeric(df['Income (USD)'], errors='coerce')
print("Before Replacing:\n\n",df['Income (USD)'].head(8))
print("\nMean of 'Income (USD)' Column:",df['Income (USD)'].mean())
dp=df['Income (USD)'].fillna(df['Income (USD)'].mean())
print("\nAfter Replacing with Mean:\n\n",dp.head(8))
# Out:
# Before Replacing:
#
#  0    1933.05
# 1    4952.91
# 2     988.19
# 3        NaN
# 4    2614.77
# 5    1234.92
# 6    2361.56
# 7        NaN
# Name: Income (USD), dtype: float64
#
# Mean of 'Income (USD)' Column: 2576.8671739130436
#
# After Replacing with Mean:
#
#  0    1933.050000
# 1    4952.910000
# 2     988.190000
# 3    2576.867174
# 4    2614.770000
# 5    1234.920000
# 6    2361.560000
# 7    2576.867174
# Name: Income (USD), dtype: float64

# %% [markdown]
# ## Replacing with Median Value

# %%
df=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Income (USD)'] = p.to_numeric(df['Income (USD)'], errors='coerce')
print("Before Replacing:\n\n",df['Income (USD)'].head(8))
print("\nMedian of 'Income (USD)' Column:",df['Income (USD)'].median())
dp=df['Income (USD)'].fillna(df['Income (USD)'].mean())
print("\nAfter Replacing with Mean:\n\n",dp.head(8))
# Out:
# Before Replacing:
#
#  0    1933.05
# 1    4952.91
# 2     988.19
# 3        NaN
# 4    2614.77
# 5    1234.92
# 6    2361.56
# 7        NaN
# Name: Income (USD), dtype: float64
#
# Median of 'Income (USD)' Column: 2354.2200000000003
#
# After Replacing with Mean:
#
#  0    1933.050000
# 1    4952.910000
# 2     988.190000
# 3    2576.867174
# 4    2614.770000
# 5    1234.920000
# 6    2361.560000
# 7    2576.867174
# Name: Income (USD), dtype: float64

# %% [markdown]
# ## Replacing with Mode Value

# %%
f=p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Income (USD)'] = p.to_numeric(df['Income (USD)'], errors='coerce')
print("Before Replacing:\n\n",df['Income (USD)'].head(7))
print("\nMode of 'Income (USD)' Column:",df['Income (USD)'].mode()[0])
dp=df['Income (USD)'].fillna(df['Income (USD)'].mode()[0])
print("\nAfter Replacing with Mode:\n\n",dp.head(7))
# Out:
# Before Replacing:
#
#  0    1933.05
# 1    4952.91
# 2     988.19
# 3        NaN
# 4    2614.77
# 5    1234.92
# 6    2361.56
# Name: Income (USD), dtype: float64
#
# Mode of 'Income (USD)' Column: 700.07
#
# After Replacing with Mode:
#
#  0    1933.05
# 1    4952.91
# 2     988.19
# 3     700.07
# 4    2614.77
# 5    1234.92
# 6    2361.56
# Name: Income (USD), dtype: float64

# %% [markdown]
# ## Univariate Outliers

# %%
import pandas as p
import matplotlib.pyplot as plt
import seaborn as sns
df = p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Income (USD)'] = p.to_numeric(df['Income (USD)'], errors='coerce')
Q1 = df['Income (USD)'].quantile(0.25)
Q3 = df['Income (USD)'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
outliers = df[(df['Income (USD)'] < lower_bound) | (df['Income (USD)'] > upper_bound)]
print("Identified Outliers:\n", outliers)
df_no_outliers = df[(df['Income (USD)'] >= lower_bound) & (df['Income (USD)'] <= upper_bound)]
print("\nOriginal DataFrame shape:", df.shape)
print("DataFrame shape after removing outliers:", df_no_outliers.shape)
plt.figure(figsize=(10, 6))
sns.boxplot(df['Income (USD)'])
plt.xlabel('Income (USD)')
plt.ylabel('values')
plt.title('Boxplot of Income (USD)')
plt.show()
# Out:
# Identified Outliers:
#     Customer ID               Name Gender  Age  Income (USD)  \
# 1      C-33999  America Calderone      M   32       4952.91
# 27     C-44863     Gerard Forsman      F   18       5350.94
# 36     C-21055    Travis Priester      F   61       5302.28
# 39     C-24451     Margareta Wind      M   18       7885.56
# 41     C-48527       Mana Chattin      F   54       5330.72
#
#               Profession    Location  Loan Amount Request (USD)  \
# 1                Working  Semi-Urban                   46837.47
# 27  Commercial associate  Semi-Urban                   99492.44
# 36               Working       Rural                  186715.38
# 39  Commercial associate       Urban                  121963.50
# 41               Working  Semi-Urban                  133531.81
#
#     Current Loan Expenses (USD)  Credit Score Has Active Credit Card  \
# 1                        495.81        780.40            Unpossessed
# 27                       516.71        733.68               Inactive
# 36                       527.81        748.38                 Active
# 39                       587.80        721.18            Unpossessed
# 41                       535.77        861.21                 Active
#
#     Property ID  Property Age Property Location  Property Price  \
# 1           608       4952.91             Rural        54791.00
# 27          344       5350.94             Rural       188950.33
# 36           43       5302.28        Semi-Urban       270558.30
# 39          530       7885.56             Urban       142645.25
# 41          467       5330.72             Urban       170214.99
#
#     Loan Sanction Amount (INR)
# 1                     37469.98
# 27                        0.00
# 36                   121365.00
# 39                    85374.45
# 41                   100148.86
#
# Original DataFrame shape: (50, 16)
# DataFrame shape after removing outliers: (41, 16)

# %% [markdown]
# ## Multivariate Outliers

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Income (USD)'] = pd.to_numeric(df['Income (USD)'], errors='coerce')
plt.figure(figsize=(12, 6))
plt.subplot(1, 1, 1)
plt.boxplot(df['Income (USD)'].dropna(), vert=False)
plt.title('Boxplot of Income (USD)')
plt.xlabel('Income (USD)')
plt.show()

# %% [markdown]
# ## Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv')
 
info=df.info() 

print("\n\n\nis_na:\n\n",df.isna().head(7)) 
 
is_null_su=df.isna().sum() 
print("\n\n\nCount of all Missing values:\n\n",df.isna().sum())

# Display the first few rows of the dataframe to understand its structure
print("Data:\n ",df.head())

# Select numeric columns for covariance and correlation calculations
numeric_columns = [
    'Age', 'Income (USD)', 'Loan Amount Request (USD)', 
    'Current Loan Expenses (USD)', 'Credit Score', 
    'Property Age', 'Property Price', 'Loan Sanction Amount (INR)'
]

# Drop rows with missing values in the selected columns
df_numeric = df[numeric_columns].dropna()

# Calculate covariance matrix
cov_matrix = df_numeric.cov()
print("Covariance Matrix:")
print(cov_matrix)

# Calculate correlation matrix
corr_matrix = df_numeric.corr()
print("Correlation Matrix:")
print(corr_matrix)



# Calculate mean and median for numeric columns
mean_values = df[numeric_columns].mean()
median_values = df[numeric_columns].median()

print("Mean Values:")
print(mean_values)
print("\nMedian Values:")
print(median_values)

# Univariate and Multivariate Distribution Plots
# Univariate
plt.figure(figsize=(10, 6))
sns.histplot(df['Loan Amount Request (USD)'].dropna(), bins=30, kde=True)
plt.title('Histogram of Loan Amount Request (USD)')
plt.xlabel('Loan Amount Request (USD)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

#Multivariate
plt.figure(figsize=(16, 10))
df.boxplot(column=numeric_columns)
plt.xticks(rotation=45, ha='right')
plt.title('Box Plot for Numeric Columns')
plt.ylabel('Values')
plt.show()

#Comparision plot of Univariate and Multivariate 
plt.figure(figsize=(12, 8))
sns.boxplot(x='Property Location', y='Property Price', data=df)
plt.xticks(rotation=45)  
plt.title('Property Price Distribution by Property Location')
plt.xlabel('Location')
plt.ylabel('Property Price')
plt.show()

df_melted = df.melt(value_vars=numeric_columns, var_name='Variable', value_name='Value')
plt.figure(figsize=(14, 8))
sns.boxplot(x='Variable', y='Value', data=df_melted)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.title('Boxplot of Numeric Variables')
plt.xlabel('Variable')
plt.ylabel('Value')
plt.show()

#Univariate and Multivariate composition plots
gender_counts = df['Gender'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Gender')
plt.show()


df_numeric = df[numeric_columns]
df.set_index('Property Location', inplace=True)

ax = df_numeric.plot(kind='bar', stacked=True, figsize=(14, 8), colormap='tab20')

plt.title('Stacked Bar Plot of Numeric Variables by Property Location')
plt.xlabel('Property Location')
plt.ylabel('Value')
plt.legend(title='Variable', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()  # Adjust layout to fit labels and legend
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer ID                  50 non-null     object
#  1   Name                         50 non-null     object
#  2   Gender                       50 non-null     object
#  3   Age                          50 non-null     int64
#  4   Income (USD)                 46 non-null     float64
#  5   Profession                   50 non-null     object
#  6   Location                     50 non-null     object
#  7   Loan Amount Request (USD)    50 non-null     float64
#  8   Current Loan Expenses (USD)  50 non-null     float64
#  9   Credit Score                 49 non-null     float64
#  10  Has Active Credit Card       46 non-null     object
#  11  Property ID                  50 non-null     int64
#  12  Property Age                 46 non-null     float64
#  13  Property Location            50 non-null     object
#  14  Property Price               50 non-null     float64
#  15  Loan Sanction Amount (INR)   50 non-null     float64
# dtypes: float64(7), int64(2), object(7)
# memory usage: 6.4+ KB
#
#
#
# is_na:
#
#     Customer ID   Name  Gender    Age  Income (USD)  Profession  Location  \
# 0        False  False   False  False         False       False     False
# 1        False  False   False  False         False       False     False
# 2        False  False   False  False         False       False     False
# 3        False  False   False  False          True       False     False
# 4        False  False   False  False         False       False     False
# 5        False  False   False  False         False       False     False
# 6        False  False   False  False         False       False     False
#
#    Loan Amount Request (USD)  Current Loan Expenses (USD)  Credit Score  \
# 0                      False                        False         False
# 1                      False                        False         False
# 2                      False                        False         False
# 3                      False                        False         False
# 4                      False                        False         False
# 5                      False                        False         False
# 6                      False                        False         False
#
#    Has Active Credit Card  Property ID  Property Age  Property Location  \
# 0                    True        False         False              False
# 1                   False        False         False              False
# 2                   False        False         False              False
# 3                   False        False          True              False
# 4                   False        False         False              False
# 5                   False        False         False              False
# 6                   False        False         False              False
#
#    Property Price  Loan Sanction Amount (INR)
# 0           False                       False
# 1           False                       False
# 2           False                       False
# 3           False                       False
# 4           False                       False
# 5           False                       False
# 6           False                       False
#
#
#
# Count of all Missing values:
#
#  Customer ID                    0
# Name                           0
# Gender                         0
# Age                            0
# Income (USD)                   4
# Profession                     0
# Location                       0
# Loan Amount Request (USD)      0
# Current Loan Expenses (USD)    0
# Credit Score                   1
# Has Active Credit Card         4
# Property ID                    0
# Property Age                   4
# Property Location              0
# Property Price                 0
# Loan Sanction Amount (INR)     0
# dtype: int64
# Data:
#     Customer ID               Name Gender  Age  Income (USD) Profession  \
# 0     C-36995   Frederica Shealy      F   56       1933.05    Working
# 1     C-33999  America Calderone      M   32       4952.91    Working
# 2      C-3770      Rosetta Verne      F   65        988.19  Pensioner
# 3     C-26480         Zoe Chitty      F   65           NaN  Pensioner
# 4     C-23459       Afton Venema      F   31       2614.77    Working
#
#      Location  Loan Amount Request (USD)  Current Loan Expenses (USD)  \
# 0  Semi-Urban                   72809.58                       241.08
# 1  Semi-Urban                   46837.47                       495.81
# 2  Semi-Urban                   45593.04                       171.95
# 3       Rural                   80057.92                       298.54
# 4  Semi-Urban                  113858.89                       491.41
#
#    Credit Score Has Active Credit Card  Property ID  Property Age  \
# 0        809.44                    NaN          746       1933.05
# 1        780.40            Unpossessed          608       4952.91
# 2        833.15            Unpossessed          546        988.19
# 3        832.70            Unpossessed          890           NaN
# 4        745.55                 Active          715       2614.77
#
#   Property Location  Property Price  Loan Sanction Amount (INR)
# 0             Rural       119933.46                    54607.18
# 1             Rural        54791.00                    37469.98
# 2             Urban        72440.58                    36474.43
# 3        Semi-Urban       121441.51                    56040.54
# 4        Semi-Urban       208567.91                    74008.28
# Covariance Matrix:
#                                        Age  Income (USD)  \
# Age                             278.936364 -6.231117e+03
# Income (USD)                  -6231.116894  2.163937e+06
# Loan Amount Request (USD)     56705.139697  3.370195e+07
# Current Loan Expenses (USD)    -248.507545  1.276820e+05
# Credit Score                    519.723303 -6.067065e+03
# Property Age                  -6231.116894  2.163937e+06
# Property Price               137881.520106  4.383149e+07
# Loan Sanction Amount (INR)   176151.765348  1.941671e+07
#
#                              Loan Amount Request (USD)  \
# Age                                       5.670514e+04
# Income (USD)                              3.370195e+07
# Loan Amount Request (USD)                 2.499258e+09
# Current Loan Expenses (USD)               6.951556e+06
# Credit Score                             -1.167374e+05
# Property Age                              3.370195e+07
# Property Price                            3.490958e+09
# Loan Sanction Amount (INR)                1.178909e+09
#
#                              Current Loan Expenses (USD)  Credit Score  \
# Age                                        -2.485075e+02  5.197233e+02
# Income (USD)                                1.276820e+05 -6.067065e+03
# Loan Amount Request (USD)                   6.951556e+06 -1.167374e+05
# Current Loan Expenses (USD)                 2.853285e+04 -4.747571e+02
# Credit Score                               -4.747571e+02  5.079446e+03
# Property Age                                1.276820e+05 -6.067065e+03
# Property Price                              9.511192e+06  4.113312e+03
# Loan Sanction Amount (INR)                  2.419589e+06  1.033368e+06
#
#                              Property Age  Property Price  \
# Age                         -6.231117e+03    1.378815e+05
# Income (USD)                 2.163937e+06    4.383149e+07
# Loan Amount Request (USD)    3.370195e+07    3.490958e+09
# Current Loan Expenses (USD)  1.276820e+05    9.511192e+06
# Credit Score                -6.067065e+03    4.113312e+03
# Property Age                 2.163937e+06    4.383149e+07
# Property Price               4.383149e+07    5.284672e+09
# Loan Sanction Amount (INR)   1.941671e+07    1.735945e+09
#
#                              Loan Sanction Amount (INR)
# Age                                        1.761518e+05
# Income (USD)                               1.941671e+07
# Loan Amount Request (USD)                  1.178909e+09
# Current Loan Expenses (USD)                2.419589e+06
# Credit Score                               1.033368e+06
# Property Age                               1.941671e+07
# Property Price                             1.735945e+09
# Loan Sanction Amount (INR)                 1.523610e+09
# Correlation Matrix:
#                                   Age  Income (USD)  \
# Age                          1.000000     -0.253624
# Income (USD)                -0.253624      1.000000
# Loan Amount Request (USD)    0.067915      0.458276
# Current Loan Expenses (USD) -0.088088      0.513848
# Credit Score                 0.436628     -0.057869
# Property Age                -0.253624      1.000000
# Property Price               0.113565      0.409878
# Loan Sanction Amount (INR)   0.270208      0.338156
#
#                              Loan Amount Request (USD)  \
# Age                                           0.067915
# Income (USD)                                  0.458276
# Loan Amount Request (USD)                     1.000000
# Current Loan Expenses (USD)                   0.823197
# Credit Score                                 -0.032764
# Property Age                                  0.458276
# Property Price                                0.960572
# Loan Sanction Amount (INR)                    0.604141
#
#                              Current Loan Expenses (USD)  Credit Score  \
# Age                                            -0.088088      0.436628
# Income (USD)                                    0.513848     -0.057869
# Loan Amount Request (USD)                       0.823197     -0.032764
# Current Loan Expenses (USD)                     1.000000     -0.039436
# Credit Score                                   -0.039436      1.000000
# Property Age                                    0.513848     -0.057869
# Property Price                                  0.774557      0.000794
# Loan Sanction Amount (INR)                      0.366971      0.371458
#
#                              Property Age  Property Price  \
# Age                             -0.253624        0.113565
# Income (USD)                     1.000000        0.409878
# Loan Amount Request (USD)        0.458276        0.960572
# Current Loan Expenses (USD)      0.513848        0.774557
# Credit Score                    -0.057869        0.000794
# Property Age                     1.000000        0.409878
# Property Price                   0.409878        1.000000
# Loan Sanction Amount (INR)       0.338156        0.611773
#
#                              Loan Sanction Amount (INR)
# Age                                            0.270208
# Income (USD)                                   0.338156
# Loan Amount Request (USD)                      0.604141
# Current Loan Expenses (USD)                    0.366971
# Credit Score                                   0.371458
# Property Age                                   0.338156
# Property Price                                 0.611773
# Loan Sanction Amount (INR)                     1.000000
# Mean Values:
# Age                                39.960000
# Income (USD)                     2576.867174
# Loan Amount Request (USD)       84786.879600
# Current Loan Expenses (USD)       378.209000
# Credit Score                      746.819388
# Property Age                     2576.867174
# Property Price                 126106.198400
# Loan Sanction Amount (INR)      43317.895800
# dtype: float64
#
# Median Values:
# Age                                40.000
# Income (USD)                     2354.220
# Loan Amount Request (USD)       74191.970
# Current Loan Expenses (USD)       346.935
# Credit Score                      747.210
# Property Age                     2354.220
# Property Price                 117739.795
# Loan Sanction Amount (INR)      35350.135
# dtype: float64

# %% [markdown]
# ## Standard Deviation

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
df['Loan Amount Request (USD)'] = pd.to_numeric(df['Loan Amount Request (USD)'], errors='coerce')
std = df['Loan Amount Request (USD)'].std()
print("Standard Deviation of Loan Amount Request (USD):", std)
# Out:
# Standard Deviation of Loan Amount Request (USD): 53981.76807153175

# %% [markdown]
# ## Perform SVC/SVR , Random Forest Regressor/Random Forest Classifier for Mini Project (both Regression and Classification Datasets)

# %%
import pandas as p
from sklearn.model_selection import train_test_split as ttp
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
data = p.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loanno_reg1.csv")
data.drop(['Customer ID','Name'],axis=1, inplace=True)
data.dropna(axis=0,inplace=True)
labelencoder = LabelEncoder()
for column in ['Gender', 'Profession', 'Location', 'Has Active Credit Card', 'Property Location']:
    data[column] = labelencoder.fit_transform(data[column])
x = data.drop(columns=['Loan Sanction Amount (INR)'])  
Y=data['Loan Sanction Amount (INR)']
x_train, x_test, Y_train, Y_test = ttp(x, Y, test_size=0.3, random_state=42)
model3 = RandomForestRegressor()
model3.fit(x_train, Y_train)
Y_pred3 = model3.predict(x_test)
print("Accuracy of RandomForestRegressor: ",r2_score(Y_test,Y_pred3))
# Out:
# Accuracy of RandomForestRegressor:  0.45704374042937523

# %%
model4 = SVR(kernel='rbf')
model4.fit(x_train, Y_train)
Y_pred4 = model4.predict(x_test)
print("Accuracy of SupportVectorRegressor: ",r2_score(Y_test,Y_pred4))
# Out:
# Accuracy of SupportVectorRegressor:  -0.027346448476955443

# %% [markdown]
# ## Perform Logistic Regression on Regression Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
df = pd.read_csv("C:\\Users\\User\\OneDrive\\Desktop\\repo\\loan_prediction1.csv")
df.drop(columns=['Loan_ID'], inplace=True)
df.dropna(axis=0,inplace=True)
labelencoder = LabelEncoder()
for column in ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Loan_Status']:
    df[column] = labelencoder.fit_transform(df[column])
X = df.drop(columns=['Loan_Status'])  
y = df['Loan_Status']  
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print("Accuracy of Logistic Regression: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy of Logistic Regression:  0.8181818181818182
